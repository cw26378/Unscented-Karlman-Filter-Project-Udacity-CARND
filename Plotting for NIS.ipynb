# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

os.chdir('/Users/austen/Car-ND/CarND-Unscented-Kalman-Filter-Project-master')

with open("NIS_list_laser.txt") as f:
    NIS_laser = f.readlines()
NIS_laser = [float(x.strip()) for x in NIS_laser] 

with open("NIS_list_radar.txt") as f:
    NIS_radar = f.readlines()
NIS_radar = [float(x.strip()) for x in NIS_radar]

# %%
plt.figure(figsize=(10,5))
plt.plot(range(0,len(NIS_laser)), NIS_laser, color='b', label = 'laser NIS')
plt.axhline(y = 5.991, color='r', linestyle='-', label = '95% for df = 2')
# Place a legend to the right of this smaller subplot.
plt.legend(bbox_to_anchor=(0.8, 1), loc=2, borderaxespad=0.)
plt.xlim(0, 250)
plt.show()
#plt.plot(right_fitx, ploty, color='yellow')
#plt.xlim(0, 1280)
#plt.ylim(720, 0)

# %%
plt.figure(figsize=(10,5))
plt.plot(range(0,len(NIS_radar)), NIS_radar, color='b', label = 'radar NIS')
plt.axhline(y = 7.815, color='r', linestyle='-', label = '95% for df = 3')
# Place a legend to the right of this smaller subplot.
plt.legend(bbox_to_anchor=(0.8, 1), loc=2, borderaxespad=0.)
plt.xlim(0, 250)
plt.show()
